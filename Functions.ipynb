# %% [markdown]
# <a href="https://colab.research.google.com/github/Srishylam-code/Python/blob/main/Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def kar(a):
  if a==1:
    return
  i=2
  while(a%i!=0):
    i=i+1
  print(i,end=" ")
  kar(a/i)

kar(100)
# Out:
# 2 2 5 5
